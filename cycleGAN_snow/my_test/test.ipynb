# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import os.path as Path
from PIL import Image
import os

# %%
os.getcwd()
# Out:
# '/Users/pjs/Downloads/CS280/proj/cycleGAN/pytorch-CycleGAN-and-pix2pix/my_test'

# %%
directory = Path.join('..','..','nature','trainA')
# output = Path.join('..','datasets','nature','trainA')

# %%
os.listdir(output)
# Out:
# []

# %%
img_list = os.listdir(directory)

# %%
len(img_list)
# Out:
# 1329

# %%
test= Path.join('..','datasets','sidewalk','trainA')
img_list = os.listdir(test)

# %%
for t in img_list:
    x = Path.join(test, t)
    Image.open(x).convert('RGB')

# %%
# for i in range(1,10):
for img_test in img_list:
#     cur = Path.join(directory, '{}_B.jpg'.format(i))
    cur = Path.join(output, img_test)
    img = plt.imread(cur)
# Out:
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# ...

# %%
directory = Path.join('..','..','nature','trainB')
img_list = os.listdir(directory)
for img_ori in img_list:
    cur_path = Path.join(directory, img_ori)
    cur = Image.open(cur_path)
#     resized = cur.resize((256,256))
#     cur.save(Path.join(output, img_ori))
